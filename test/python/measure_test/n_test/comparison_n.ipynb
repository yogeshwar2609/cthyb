# %%
from pytriqs_utilities import *
# %matplotlib inline
# Out:
# Starting on 1 Nodes at : 2016-01-14 13:19:10.258144
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d18099e193da> in <module>()
# ----> 1 from pytriqs_utilities import *
#       2 get_ipython().magic(u'matplotlib inline')
#
# /home/pseth/Work/py_modules/pytriqs_utilities.py in <module>()
#       4
#       5 from pytriqs.applications.impurity_solvers.cthyb import *
# ----> 6 from pytriqs.applications.dft import *
#       7 from pytriqs.dos import *
#       8
#
# ImportError: No module named dft

# %%
ar = HDFArchive('anderson_static_0.5.block.h5','r')
print ar['Nup']
print ar['Ndn']

# %%
ar = HDFArchive('anderson_twobody_0.5.block.h5','r')
G_iw = ar['G_iw']
print G_iw.total_density()
print G_iw['up'].density()
print G_iw['dn'].density()

# %%
oplot(ar['G_tau'])

# %%
oplot(ar['n_corr'])
